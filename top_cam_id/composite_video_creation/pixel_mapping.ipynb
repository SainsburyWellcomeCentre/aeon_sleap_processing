# %% [markdown]
# Image registration to create a pixel map between top camera (A) and quadrant camera (B) with overlapping fields of view (FOV), where quadtant camera's FOV is a subset and a rotated version of top camera's FOV.
# 1. Exrtact and Load Images: Dynamically extract random matching frames from the video frames for both Camera A and Camera B.
# 2. Detect Features: Use ORB (Oriented FAST and Rotated BRIEF) to detect keypoints and get descriptors.
# 3. Match Features: Use a matcher (rute-Force matcher with Hamming distance) to find corresponding keypoints between the images. Keep best matches.
# 4. Compute Homography: Estimate the homography matrix (matrix that best transforms the matched keypoints from Camera B's frame of reference to Camera A's frame of reference) to align the images (rotation, translation, scaling).
# 5. Pixel map: Get the pixel map from A to B and vice versa based on this.
# 6. Quality checks base on homography matrix.
# 7. Multi-frame averaging: Perform these computation on many frames and average over individual homography matrices that pass checks for more accurate results.
# 8. Visualise results by applying the homography to transform Camera B's images to align with Camera A's perspective.
# 9. Save map, H, and visualisation.

# %% [markdown]
# This method seems to work better then other tried, becasue:
#
# - can deal with low number of unique features in the image (feature matching algorithms failed)
# - can deal with orientation and perspective differences (template matching (= find B within A) failed)

# %% [markdown]
# Homography matrix explanation:
#
# - ( h_{11} ) and ( h_{22} ): These elements represent scaling and rotation. They affect how the image is scaled and rotated around the origin.
# - ( h_{12} ) and ( h_{21} ): These elements represent shear. They affect how the image is skewed.
# - ( h_{13} ) and ( h_{23} ): These elements represent translation. They affect how the image is shifted in the x and y directions.
# - ( h_{31} ) and ( h_{32} ): These elements represent perspective distortion. They affect how the image is warped to simulate a change in viewpoint.
# - ( h_{33} ): This element is typically 1 for normalization purposes.

# %%
"""Imports"""
import cv2
import os
import numpy as np
import matplotlib.pyplot as plt
import random


"""Define constants"""
# this shoud be run for each experiment and arena (on a random chunk at start of experiment)

# experiment = 'social0.2'
# arena = 'AEON3'
# run_start = '2024-01-31T10-28-39'
# chunk_start = '2024-01-31T11-00-00'

# experiment = 'social0.2'
# arena = 'AEON4'
# run_start = '2024-02-09T16-39-14'
# chunk_start = '2024-02-10T11-00-00'

# experiment = 'social0.3'
# arena = 'AEON3'
# run_start = '2024-06-09T10-03-46'
# chunk_start = '2024-06-10T16-00-00'

# experiment = 'social0.3'
# arena = 'AEON4'
# run_start = '2024-06-08T18-27-09'
# chunk_start = '2024-06-12T10-00-00'

# experiment = 'social0.4'
# arena = 'AEON3'
# run_start = '2024-08-28T10-09-33'
# chunk_start = '2024-08-28T14-00-00'

experiment = 'social0.4'
arena = 'AEON4'
run_start = '2024-08-16T14-30-28'
chunk_start = '2024-08-18T14-00-00'

camera_a = 'CameraTop'
camera_b_list = ['CameraSouth', 'CameraNorth', 'CameraEast', 'CameraWest']
base_path = '/ceph/aeon/aeon'
video_path = base_path + f'/data/raw/{arena}/{experiment}/{run_start}'
video_path_a = video_path + f'/{camera_a}/{camera_a}_{chunk_start}.avi'
results_dir = base_path + f'/code/scratchpad/Orsi/pixel_mapping/pixel_mapping_results/{experiment}/{arena}'
os.makedirs(results_dir, exist_ok=True)

"""Define utility functions"""
def extract_frame(cap, frame_idx):
    """Extract a single frame from the video at the given index."""
    cap.set(cv2.CAP_PROP_POS_FRAMES, frame_idx)
    ret, frame = cap.read()
    return frame if ret else None

def save_plot(img_a, img_b, img_b_aligned, kp_a, kp_b, matches, mask, title, save_path):
    """Save the final plot with warping based on average H."""
    plt.figure(figsize=(12, 6))
    plt.subplot(1, 3, 1)
    plt.imshow(img_a, cmap='gray')
    plt.title("Camera A (Original)")

    plt.subplot(1, 3, 2)
    plt.imshow(img_b, cmap='gray')
    plt.title("Camera B (Original)")

    plt.subplot(1, 3, 3)
    plt.imshow(img_b_aligned, cmap='gray')
    plt.title("Camera B (Aligned to A)")

    plt.savefig(save_path)
    plt.close()
    
def warp_image(img_b, H, img_a_shape):
    """
    Warp Image B to Image A's perspective using the homography matrix.
    """
    # Apply homography to warp Image B
    img_b_aligned = cv2.warpPerspective(img_b, H, (img_a_shape[1], img_a_shape[0]))
    return img_b_aligned

def save_homography_and_maps(H, map_a_to_b, map_b_to_a, camera_b):
    """Save the homography matrix and pixel maps."""
    np.save(os.path.join(results_dir, f'H_{camera_b}.npy'), H)
    np.save(os.path.join(results_dir, f'map_a_to_b_{camera_b}.npy'), map_a_to_b)
    np.save(os.path.join(results_dir, f'map_b_to_a_{camera_b}.npy'), map_b_to_a)
    print(f"Saved homography and pixel maps for {camera_b}.")

def calculate_pixel_mapping(kp_a, kp_b, H, img_shape):
    """Calculate pixel mappings between two images."""
    # Create empty maps for the pixel correspondence
    map_a_to_b = np.zeros((img_shape[0], img_shape[1], 2), dtype=np.float32)
    map_b_to_a = np.zeros((img_shape[0], img_shape[1], 2), dtype=np.float32)

    # Calculate the pixel mapping
    for y in range(img_shape[0]):
        for x in range(img_shape[1]):
            # Map from A to B
            pt_a = np.array([[x, y]], dtype=np.float32).reshape(-1, 1, 2)
            pt_b = cv2.perspectiveTransform(pt_a, H)
            map_a_to_b[y, x] = pt_b[0, 0]

            # Map from B to A
            pt_b_inv = cv2.perspectiveTransform(pt_b, np.linalg.inv(H))
            map_b_to_a[y, x] = pt_b_inv[0, 0]

    return map_a_to_b, map_b_to_a

def process_video_frames(video_path_a, video_path_b, camera_b, num_good_frames=50):
    """Process frames from two videos dynamically until 20 good frames are found."""
    cap_a = cv2.VideoCapture(video_path_a)
    cap_b = cv2.VideoCapture(video_path_b)

    total_frames = int(cap_a.get(cv2.CAP_PROP_FRAME_COUNT))
    good_homographies = []
    frames_checked = 0

    while len(good_homographies) < num_good_frames:
        frame_idx = random.randint(0, total_frames - 1)  # Randomly select a frame index

        # Extract frames for both cameras
        frame_a = extract_frame(cap_a, frame_idx)
        frame_b = extract_frame(cap_b, frame_idx)

        if frame_a is None or frame_b is None:
            print(f"Could not read frames at index {frame_idx}. Skipping...")
            continue

        # Convert frames to grayscale
        img_a = cv2.cvtColor(frame_a, cv2.COLOR_BGR2GRAY)
        img_b = cv2.cvtColor(frame_b, cv2.COLOR_BGR2GRAY)

        # Detect and match features
        kp_a, kp_b, matches = detect_and_match_features(img_a, img_b)
        if len(matches) < 4:  # Not enough matches to compute a homography
            print("Not enough matches. Skipping frame...")
            continue

        # Compute homography
        H, mask = compute_homography(kp_a, kp_b, matches)

        if H is not None and is_perspective_good(H) and is_rotation_good(H, camera_b) and is_shear_good(H):
            good_homographies.append(H)
            print(f"Valid Homography found for frame index {frame_idx} (total valid: {len(good_homographies)})")
        else:
            print(f"Invalid Homography at frame index {frame_idx}.")

    cap_a.release()
    cap_b.release()
    
    if len(good_homographies) < num_good_frames:
        print(f"Analysis could not complete for {camera_b}. Checked {frames_checked} frames but found only {len(good_homographies)} good homographies.")
        return None, None

    # Compute the average homography
    H_avg = np.mean(good_homographies, axis=0)
    print(f"Averaged Homography:\n{H_avg} based on {len(good_homographies)} valid homographies.")

    # Use the last valid frames for final plotting
    img_b_aligned = warp_image(img_b, H_avg, img_a.shape)

    # Calculate pixel maps
    map_a_to_b, map_b_to_a = calculate_pixel_mapping(kp_a, kp_b, H_avg, img_a.shape)

    # Save results
    save_plot(img_a, img_b, img_b_aligned, kp_a, kp_b, matches, mask, 'Final Averaged Homography',
              os.path.join(results_dir, f'final_plot_{camera_b}.png'))
    save_homography_and_maps(H_avg, map_a_to_b, map_b_to_a, camera_b)

    return H_avg, good_homographies

def detect_and_match_features(img_a, img_b, nfeatures=1000):
    """Detect and match features between two images using ORB."""
    orb = cv2.ORB_create(nfeatures=nfeatures)
    kp_a, des_a = orb.detectAndCompute(img_a, None)
    kp_b, des_b = orb.detectAndCompute(img_b, None)
    bf = cv2.BFMatcher(cv2.NORM_HAMMING, crossCheck=True)
    matches = bf.match(des_a, des_b)
    matches = sorted(matches, key=lambda x: x.distance)
    return kp_a, kp_b, matches

def compute_homography(kp_a, kp_b, matches):
    """Compute the homography matrix to map Image B to Image A."""
    src_pts = np.float32([kp_b[m.trainIdx].pt for m in matches]).reshape(-1, 1, 2)
    dst_pts = np.float32([kp_a[m.queryIdx].pt for m in matches]).reshape(-1, 1, 2)
    H, mask = cv2.findHomography(src_pts, dst_pts, cv2.RANSAC, 5.0)
    return H, mask

def is_perspective_good(H, perspective_threshold=1e-3):
    """Check if the homography matrix is good based on perspective distortion."""
    h31, h32 = H[2, 0], H[2, 1]
    return abs(h31) <= perspective_threshold and abs(h32) <= perspective_threshold

def is_shear_good(H, shear_threshold=1):
    """Check if the homography matrix is good based on shearing distortion."""
    h12, h21 = H[0, 1], H[1, 0]
    return abs(h12) <= shear_threshold and abs(h21) <= shear_threshold

def is_rotation_good(H, camera_b, tolerance=15):
    """Check if the homography matrix has a rotation component within the expected range."""
    R = H[0:2, 0:2]
    theta = np.arctan2(R[1, 0], R[0, 0]) * 180 / np.pi
    theta = theta % 360

    if camera_b == 'CameraWest':
        expected_rotation = 0
    elif camera_b == 'CameraNorth':
        expected_rotation = 90
    elif camera_b == 'CameraEast':
        expected_rotation = 180
    elif camera_b == 'CameraSouth':
        expected_rotation = 270
    else:
        raise ValueError(f"Unrecognized camera_b: {camera_b}")

    circular_difference = min(abs(theta - expected_rotation), 360 - abs(theta - expected_rotation))
    return circular_difference <= tolerance

"""Run dynamic extraction and processing for all CameraBs""" 
for camera_b in camera_b_list:
    video_path_b = video_path + f'/{camera_b}/{camera_b}_{chunk_start}.avi'
    print(f"Processing frames for Camera B: {camera_b}")
    H_avg, homographies = process_video_frames(video_path_a, video_path_b, camera_b)
# Out:
# Processing frames for Camera B: CameraSouth
# Valid Homography found for frame index 48514 (total valid: 1)
# Valid Homography found for frame index 80571 (total valid: 2)
# Valid Homography found for frame index 8304 (total valid: 3)
# Valid Homography found for frame index 113888 (total valid: 4)
# Valid Homography found for frame index 176108 (total valid: 5)
# Valid Homography found for frame index 143686 (total valid: 6)
# Valid Homography found for frame index 35908 (total valid: 7)
# Valid Homography found for frame index 22539 (total valid: 8)
# Valid Homography found for frame index 57108 (total valid: 9)
# Valid Homography found for frame index 3034 (total valid: 10)
# Valid Homography found for frame index 15481 (total valid: 11)
# Valid Homography found for frame index 176868 (total valid: 12)
# Valid Homography found for frame index 78590 (total valid: 13)
# Valid Homography found for frame index 112997 (total valid: 14)
# Valid Homography found for frame index 84526 (total valid: 15)
# Valid Homography found for frame index 55859 (total valid: 16)
# Valid Homography found for frame index 165407 (total valid: 17)
# Valid Homography found for frame index 175388 (total valid: 18)
# Valid Homography found for frame index 91875 (total valid: 19)
# Invalid Homography at frame index 113084.
# Valid Homography found for frame index 109892 (total valid: 20)
# Valid Homography found for frame index 136841 (total valid: 21)
# Valid Homography found for frame index 53608 (total valid: 22)
# Valid Homography found for frame index 86600 (total valid: 23)
# Valid Homography found for frame index 144396 (total valid: 24)
# Valid Homography found for frame index 166077 (total valid: 25)
# Valid Homography found for frame index 78642 (total valid: 26)
# Valid Homography found for frame index 147929 (total valid: 27)
# Valid Homography found for frame index 163372 (total valid: 28)
# Valid Homography found for frame index 105743 (total valid: 29)
# Invalid Homography at frame index 108245.
# Valid Homography found for frame index 138844 (total valid: 30)
# Valid Homography found for frame index 24834 (total valid: 31)
# Valid Homography found for frame index 172061 (total valid: 32)
# Valid Homography found for frame index 121560 (total valid: 33)
# Valid Homography found for frame index 117659 (total valid: 34)
# Valid Homography found for frame index 20147 (total valid: 35)
# Valid Homography found for frame index 39575 (total valid: 36)
# Valid Homography found for frame index 69561 (total valid: 37)
# Valid Homography found for frame index 79487 (total valid: 38)
# Invalid Homography at frame index 130890.
# Valid Homography found for frame index 40327 (total valid: 39)
# Valid Homography found for frame index 23963 (total valid: 40)
# Valid Homography found for frame index 17815 (total valid: 41)
# Valid Homography found for frame index 4890 (total valid: 42)
# Valid Homography found for frame index 20187 (total valid: 43)
# Valid Homography found for frame index 68448 (total valid: 44)
# Valid Homography found for frame index 54044 (total valid: 45)
# Valid Homography found for frame index 39502 (total valid: 46)
# Valid Homography found for frame index 91547 (total valid: 47)
# Invalid Homography at frame index 102322.
# Invalid Homography at frame index 172383.
# Invalid Homography at frame index 164727.
# Valid Homography found for frame index 99742 (total valid: 48)
# Valid Homography found for frame index 101424 (total valid: 49)
# Valid Homography found for frame index 84323 (total valid: 50)
# Averaged Homography:
# [[ 1.32378101e-02  4.66753113e-01  8.39487438e+01]
#  [-5.41887440e-01 -4.57613701e-02  9.78589029e+02]
#  [ 1.02079895e-06 -1.05849145e-04  1.00000000e+00]] based on 50 valid homographies.
# Saved homography and pixel maps for CameraSouth.
# Processing frames for Camera B: CameraNorth
# Valid Homography found for frame index 175548 (total valid: 1)
# Valid Homography found for frame index 162967 (total valid: 2)
# Valid Homography found for frame index 21721 (total valid: 3)
# Valid Homography found for frame index 12904 (total valid: 4)
# Valid Homography found for frame index 148780 (total valid: 5)
# Invalid Homography at frame index 109300.
# Valid Homography found for frame index 58877 (total valid: 6)
# Valid Homography found for frame index 37426 (total valid: 7)
# Valid Homography found for frame index 12879 (total valid: 8)
# Valid Homography found for frame index 87911 (total valid: 9)
# Valid Homography found for frame index 95259 (total valid: 10)
# Valid Homography found for frame index 170844 (total valid: 11)
# Invalid Homography at frame index 2752.
# Valid Homography found for frame index 79328 (total valid: 12)
# Valid Homography found for frame index 157024 (total valid: 13)
# Invalid Homography at frame index 119800.
# Valid Homography found for frame index 18751 (total valid: 14)
# Valid Homography found for frame index 51583 (total valid: 15)
# Valid Homography found for frame index 20024 (total valid: 16)
# Valid Homography found for frame index 54937 (total valid: 17)
# Valid Homography found for frame index 13579 (total valid: 18)
# Invalid Homography at frame index 145486.
# Invalid Homography at frame index 79935.
# Invalid Homography at frame index 117758.
# Invalid Homography at frame index 159626.
# Valid Homography found for frame index 99570 (total valid: 19)
# Valid Homography found for frame index 20017 (total valid: 20)
# Valid Homography found for frame index 91829 (total valid: 21)
# Valid Homography found for frame index 167291 (total valid: 22)
# Valid Homography found for frame index 28272 (total valid: 23)
# Invalid Homography at frame index 134524.
# Valid Homography found for frame index 131196 (total valid: 24)
# Invalid Homography at frame index 129715.
# Valid Homography found for frame index 129317 (total valid: 25)
# Valid Homography found for frame index 77530 (total valid: 26)
# Valid Homography found for frame index 108140 (total valid: 27)
# Valid Homography found for frame index 108309 (total valid: 28)
# Valid Homography found for frame index 156342 (total valid: 29)
# Valid Homography found for frame index 147355 (total valid: 30)
# Invalid Homography at frame index 177877.
# Valid Homography found for frame index 139883 (total valid: 31)
# Valid Homography found for frame index 17612 (total valid: 32)
# Invalid Homography at frame index 102124.
# Valid Homography found for frame index 76787 (total valid: 33)
# Invalid Homography at frame index 63998.
# Valid Homography found for frame index 163060 (total valid: 34)
# Valid Homography found for frame index 44822 (total valid: 35)
# Valid Homography found for frame index 70373 (total valid: 36)
# Valid Homography found for frame index 11269 (total valid: 37)
# Invalid Homography at frame index 3374.
# Valid Homography found for frame index 34042 (total valid: 38)
# Invalid Homography at frame index 20464.
# Valid Homography found for frame index 136722 (total valid: 39)
# Valid Homography found for frame index 49944 (total valid: 40)
# Valid Homography found for frame index 16232 (total valid: 41)
# Valid Homography found for frame index 81578 (total valid: 42)
# Valid Homography found for frame index 116483 (total valid: 43)
# Valid Homography found for frame index 129181 (total valid: 44)
# Valid Homography found for frame index 56707 (total valid: 45)
# Valid Homography found for frame index 26496 (total valid: 46)
# Valid Homography found for frame index 126622 (total valid: 47)
# Valid Homography found for frame index 138993 (total valid: 48)
# Valid Homography found for frame index 25601 (total valid: 49)
# Valid Homography found for frame index 129864 (total valid: 50)
# Averaged Homography:
# [[ 3.40675899e-02 -6.40972640e-01  1.26560247e+03]
#  [ 5.65982258e-01 -3.10187469e-02  1.40024108e+02]
#  [-2.26612589e-06 -9.76138584e-05  1.00000000e+00]] based on 50 valid homographies.
# Saved homography and pixel maps for CameraNorth.
# Processing frames for Camera B: CameraEast
# Valid Homography found for frame index 167542 (total valid: 1)
# Valid Homography found for frame index 51474 (total valid: 2)
# Valid Homography found for frame index 146272 (total valid: 3)
# Valid Homography found for frame index 113017 (total valid: 4)
# Valid Homography found for frame index 6204 (total valid: 5)
# Valid Homography found for frame index 117408 (total valid: 6)
# Valid Homography found for frame index 116488 (total valid: 7)
# Valid Homography found for frame index 30345 (total valid: 8)
# Valid Homography found for frame index 163292 (total valid: 9)
# Valid Homography found for frame index 112015 (total valid: 10)
# Valid Homography found for frame index 13185 (total valid: 11)
# Valid Homography found for frame index 176186 (total valid: 12)
# Valid Homography found for frame index 3213 (total valid: 13)
# Valid Homography found for frame index 7205 (total valid: 14)
# Valid Homography found for frame index 37255 (total valid: 15)
# Valid Homography found for frame index 145856 (total valid: 16)
# Valid Homography found for frame index 164838 (total valid: 17)
# Valid Homography found for frame index 138625 (total valid: 18)
# Valid Homography found for frame index 114235 (total valid: 19)
# Valid Homography found for frame index 151069 (total valid: 20)
# Valid Homography found for frame index 168459 (total valid: 21)
# Valid Homography found for frame index 92006 (total valid: 22)
# Valid Homography found for frame index 6762 (total valid: 23)
# Valid Homography found for frame index 51589 (total valid: 24)
# Valid Homography found for frame index 109236 (total valid: 25)
# Valid Homography found for frame index 82382 (total valid: 26)
# Valid Homography found for frame index 122486 (total valid: 27)
# Valid Homography found for frame index 66122 (total valid: 28)
# Valid Homography found for frame index 115381 (total valid: 29)
# Valid Homography found for frame index 160286 (total valid: 30)
# Valid Homography found for frame index 50204 (total valid: 31)
# Valid Homography found for frame index 99489 (total valid: 32)
# Valid Homography found for frame index 156365 (total valid: 33)
# Valid Homography found for frame index 159912 (total valid: 34)
# Valid Homography found for frame index 101386 (total valid: 35)
# Valid Homography found for frame index 158288 (total valid: 36)
# Valid Homography found for frame index 16374 (total valid: 37)
# Valid Homography found for frame index 153835 (total valid: 38)
# Valid Homography found for frame index 159134 (total valid: 39)
# Valid Homography found for frame index 86247 (total valid: 40)
# Valid Homography found for frame index 133712 (total valid: 41)
# Valid Homography found for frame index 127485 (total valid: 42)
# Valid Homography found for frame index 106086 (total valid: 43)
# Valid Homography found for frame index 40099 (total valid: 44)
# Valid Homography found for frame index 117864 (total valid: 45)
# Valid Homography found for frame index 103343 (total valid: 46)
# Valid Homography found for frame index 93000 (total valid: 47)
# Valid Homography found for frame index 48138 (total valid: 48)
# Valid Homography found for frame index 118964 (total valid: 49)
# Valid Homography found for frame index 51871 (total valid: 50)
# Averaged Homography:
# [[-5.02420286e-01 -8.85255494e-02  1.10620057e+03]
#  [ 2.77773052e-02 -5.68490132e-01  1.06634429e+03]
#  [ 3.74891418e-06 -1.00991522e-04  1.00000000e+00]] based on 50 valid homographies.
# Saved homography and pixel maps for CameraEast.
# Processing frames for Camera B: CameraWest
# Valid Homography found for frame index 82278 (total valid: 1)
# Valid Homography found for frame index 42158 (total valid: 2)
# Valid Homography found for frame index 21238 (total valid: 3)
# Valid Homography found for frame index 130698 (total valid: 4)
# Valid Homography found for frame index 71328 (total valid: 5)
# Valid Homography found for frame index 46259 (total valid: 6)
# Valid Homography found for frame index 76786 (total valid: 7)
# Valid Homography found for frame index 109092 (total valid: 8)
# Valid Homography found for frame index 46546 (total valid: 9)
# Valid Homography found for frame index 166637 (total valid: 10)
# Valid Homography found for frame index 41033 (total valid: 11)
# Valid Homography found for frame index 18830 (total valid: 12)
# Valid Homography found for frame index 73259 (total valid: 13)
# Valid Homography found for frame index 128899 (total valid: 14)
# Valid Homography found for frame index 123976 (total valid: 15)
# Valid Homography found for frame index 52888 (total valid: 16)
# Valid Homography found for frame index 108695 (total valid: 17)
# Valid Homography found for frame index 139195 (total valid: 18)
# Valid Homography found for frame index 83461 (total valid: 19)
# Valid Homography found for frame index 156779 (total valid: 20)
# Valid Homography found for frame index 167833 (total valid: 21)
# Valid Homography found for frame index 4026 (total valid: 22)
# Valid Homography found for frame index 67746 (total valid: 23)
# Valid Homography found for frame index 58473 (total valid: 24)
# Valid Homography found for frame index 148820 (total valid: 25)
# Valid Homography found for frame index 33225 (total valid: 26)
# Valid Homography found for frame index 70813 (total valid: 27)
# Valid Homography found for frame index 143771 (total valid: 28)
# Valid Homography found for frame index 135452 (total valid: 29)
# Valid Homography found for frame index 176763 (total valid: 30)
# Valid Homography found for frame index 148279 (total valid: 31)
# Valid Homography found for frame index 77623 (total valid: 32)
# Valid Homography found for frame index 53320 (total valid: 33)
# Valid Homography found for frame index 11584 (total valid: 34)
# Valid Homography found for frame index 9595 (total valid: 35)
# Valid Homography found for frame index 171950 (total valid: 36)
# Valid Homography found for frame index 84321 (total valid: 37)
# Valid Homography found for frame index 151079 (total valid: 38)
# Valid Homography found for frame index 110640 (total valid: 39)
# Valid Homography found for frame index 141374 (total valid: 40)
# Valid Homography found for frame index 114986 (total valid: 41)
# Valid Homography found for frame index 131065 (total valid: 42)
# Valid Homography found for frame index 40901 (total valid: 43)
# Valid Homography found for frame index 147974 (total valid: 44)
# Valid Homography found for frame index 142037 (total valid: 45)
# Valid Homography found for frame index 151484 (total valid: 46)
# Valid Homography found for frame index 157208 (total valid: 47)
# Valid Homography found for frame index 121664 (total valid: 48)
# Valid Homography found for frame index 48810 (total valid: 49)
# Valid Homography found for frame index 101098 (total valid: 50)
# Averaged Homography:
# [[ 5.68428273e-01 -8.09252425e-02  1.59949753e+02]
#  [ 3.19713617e-03  5.13167621e-01  1.91360268e+00]
#  [ 7.43944364e-06 -1.16773104e-04  1.00000000e+00]] based on 50 valid homographies.
# Saved homography and pixel maps for CameraWest.
